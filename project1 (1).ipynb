# %% [markdown]
# # data collection and wrangling

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\dell\Desktop/BBC.csv")

# %%
df
# Out:
#        MaritalStatus  Gender  YearlyIncome  TotalChildren  \
# 0                  5       1         90000              2
# 1                  5       1         60000              3
# 2                  5       1         60000              3
# 3                  5       2         70000              0
# 4                  5       2         80000              5
# 5                  5       1         70000              0
# 6                  5       2         70000              0
# 7                  5       1         60000              3
# 8                  5       2         60000              4
# 9                  5       1         70000              0
# 10                 5       2         70000              0
# 11                 5       1         60000              4
# 12                 5       2        100000              2
# 13                 5       1        100000              2
# 14                 5       2        100000              3
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    MaritalStatus  Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0          False   False         False          False                 False
# 1          False   False         False          False                 False
# 2          False   False         False          False                 False
# 3          False   False         False          False                 False
# 4          False   False         False          False                 False
#
#    EnglishEducation  HouseOwnerFlag  NumberCarsOwned  CommuteDistance  Region  \
# 0             False           False            False            False   False
# 1             False           False            False            False   False
# 2             False           False            False            False   False
# 3             False           False            False            False   False
# 4             False           False            False            False   False
#
#      Age  BikeBuyer
# ...

# %%
#to check the null values
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# MaritalStatus
# False    18484
# Name: MaritalStatus, dtype: int64
#
# Gender
# False    18484
# Name: Gender, dtype: int64
#
# YearlyIncome
# False    18484
# Name: YearlyIncome, dtype: int64
#
# TotalChildren
# False    18484
# Name: TotalChildren, dtype: int64
#
# NumberChildrenAtHome
# False    18484
# Name: NumberChildrenAtHome, dtype: int64
#
# EnglishEducation
# False    18484
# Name: EnglishEducation, dtype: int64
#
# HouseOwnerFlag
# False    18484
# Name: HouseOwnerFlag, dtype: int64
#
# NumberCarsOwned
# False    18484
# Name: NumberCarsOwned, dtype: int64
#
# CommuteDistance
# False    18484
# Name: CommuteDistance, dtype: int64
#
# Region
# False    18484
# Name: Region, dtype: int64
#
# Age
# False    18484
# Name: Age, dtype: int64
#
# BikeBuyer
# False    18484
# Name: BikeBuyer, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 12 columns):
# MaritalStatus           18484 non-null int64
# Gender                  18484 non-null int64
# YearlyIncome            18484 non-null int64
# TotalChildren           18484 non-null int64
# NumberChildrenAtHome    18484 non-null int64
# EnglishEducation        18484 non-null int64
# HouseOwnerFlag          18484 non-null int64
# NumberCarsOwned         18484 non-null int64
# CommuteDistance         18484 non-null int64
# Region                  18484 non-null int64
# Age                     18484 non-null int64
# BikeBuyer               18484 non-null int64
# dtypes: int64(12)
# memory usage: 1.7 MB

# %% [markdown]
# # exploratory data analysis

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# list the data types for each column
df.dtypes
# Out:
# MaritalStatus           int64
# Gender                  int64
# YearlyIncome            int64
# TotalChildren           int64
# NumberChildrenAtHome    int64
# EnglishEducation        int64
# HouseOwnerFlag          int64
# NumberCarsOwned         int64
# CommuteDistance         int64
# Region                  int64
# Age                     int64
# BikeBuyer               int64
# dtype: object

# %%
df.corr()
# Out:
#                       MaritalStatus    Gender  YearlyIncome  TotalChildren  \
# MaritalStatus              1.000000  0.006662      0.219219       0.004969
# Gender                     0.006662  1.000000      0.001965       0.004935
# YearlyIncome               0.219219  0.001965      1.000000       0.215923
# TotalChildren              0.004969  0.004935      0.215923       1.000000
# NumberChildrenAtHome      -0.037703  0.002625      0.452133       0.461224
# EnglishEducation           1.000000  0.006662      0.219219       0.004969
# HouseOwnerFlag             0.100305  0.004562      0.045714       0.185742
# NumberCarsOwned           -0.210998 -0.005058      0.466647       0.265405
# CommuteDistance           -0.084436 -0.000621      0.301731       0.168617
# Region                    -0.078538 -0.004144     -0.237180      -0.100164
# Age                        0.022550  0.001426      0.163124       0.516424
# ...

# %%
sns.regplot(x="MaritalStatus", y="BikeBuyer", data=df)
plt.ylim(0,)
# Out:
# (0, 1.050824778114883)

# %%
sns.regplot(x="YearlyIncome", y="BikeBuyer", data=df)

# %%
sns.regplot(x="EnglishEducation", y="BikeBuyer", data=df)

# %%
sns.regplot(x="Age", y="BikeBuyer", data=df)

# %%
sns.regplot(x="Region", y="BikeBuyer", data=df)

# %%
sns.regplot(x="NumberCarsOwned", y="BikeBuyer", data=df)

# %%
sns.regplot(x="HouseOwnerFlag", y="BikeBuyer", data=df)

# %%
sns.boxplot(x="Gender", y="BikeBuyer", data=df)

# %%
df.describe()#descriptive statistics
# Out:
#        MaritalStatus        Gender   YearlyIncome  TotalChildren  \
# count   18484.000000  18484.000000   18484.000000   18484.000000
# mean        3.310106      1.494103   57305.777970       1.844352
# std         1.426147      0.499979   32285.841703       1.612408
# min         1.000000      1.000000   10000.000000       0.000000
# 25%         2.000000      1.000000   30000.000000       0.000000
# 50%         3.000000      1.000000   60000.000000       2.000000
# 75%         5.000000      2.000000   70000.000000       3.000000
# max         5.000000      2.000000  170000.000000       5.000000
#
#        NumberChildrenAtHome  EnglishEducation  HouseOwnerFlag  \
# count          18484.000000      18484.000000    18484.000000
# mean               1.004058          3.310106        0.676369
# std                1.522660          1.426147        0.467874
# min                0.000000          1.000000        0.000000
# 25%                0.000000          2.000000        0.000000
# ...

# %%
#scatter plot between commute distance and bikebuyers
x=df["YearlyIncome"]#the predictor
y=df["BikeBuyer"]#the target

# %%
plt.scatter(x,y)
plt.title("scatter plot between yearly income and bike buyer")
plt.xlabel("yearlyIncome")
plt.ylabel("BikeBuyer")
# Out:
# Text(0, 0.5, 'BikeBuyer')

# %%
from scipy import stats

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['YearlyIncome'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.04355069768608242  with a P-value of P = 3.153850870433438e-09

# %% [markdown]
# # no relation

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['Gender'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.018364692487882507  with a P-value of P = 0.01253091802158315

# %% [markdown]
# # no relation

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['MaritalStatus'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.12444737865205  with a P-value of P = 1.0738616819762255e-64

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['TotalChildren'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.12715224577099055  with a P-value of P = 1.7640597589979732e-67

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['EnglishEducation'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.12444737865205  with a P-value of P = 1.0738616819762255e-64

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['HouseOwnerFlag'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.007493770002999825  with a P-value of P = 0.30831337689262506

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['NumberCarsOwned'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.18086516323343996  with a P-value of P = 1.0734970561753243e-135

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['CommuteDistance'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.130389957965504  with a P-value of P = 6.803521865424212e-71

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['Region'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.055474614432782066  with a P-value of P = 4.440277834913687e-14

# %%
#correlation statistics

pearson_coef, p_value = stats.pearsonr(df['Age'], df['BikeBuyer'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.09824039704460216  with a P-value of P = 7.12128676395854e-41

# %% [markdown]
# # model development

# %%
from pandas import read_csv
from numpy import set_printoptions
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier

# %%
array = df.values
X = array[:,0:11] 
Y = array[:,11]

# %%
test_size = .30
seed = 45
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = SVC()
model.fit(X_train, Y_train)
# Out:
# E:\STUDY\python\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
result = model.score(X_test, Y_test)

# %%
result
# Out:
# 0.781644428416877

# %%
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# E:\STUDY\python\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
result = model.score(X_test, Y_test)

# %%
result
# Out:
# 0.7787594662820051
